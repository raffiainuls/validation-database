# %% [markdown]
# ## Install Depedencies

# %%
# !pip install -r requirements.txt

# %%
# !python config.py config.yaml
# Out:
# execute query1 for oracle
# execute query1 for
#                     SELECT
#                         CAST(COALESCE(CAST(ID AS VARCHAR2(255)), '0') AS VARCHAR2(255)) AS id,
#                         MODEL
#                     FROM orders
#
# execute query1 for postgres
# execute query1 for
#                     SELECT
#                         CAST(COALESCE(CAST("ID" AS VARCHAR), '0') AS VARCHAR) AS id,
#                         "MODEL"
#                     FROM public.orders
#
# Try to connect database oracle....
# try to connect database postgres
# Connected to PostgreSQL database.
# Connected to Oracle database
# Fetched Batch 1, rows so far: 2.
# Connection to Oracle closed.
# Fetched Batch 1, rows so far: 10000.
# Fetched Batch 2, rows so far: 20000.
# Fetched Batch 3, rows so far: 30000.
# Fetched Batch 4, rows so far: 40000.
# Fetched Batch 5, rows so far: 50000.
# Fetched Batch 6, rows so far: 60000.
# Fetched Batch 7, rows so far: 70000.
# ...
